# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combine_data = pd.merge( study_results, mouse_metadata, on = "Mouse ID")

# Display the data table for preview
combine_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
()# Checking the number of mice.
mice_total = combine_data["Mouse ID"].nunique()
mice_total
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
Data_unique = combine_data[combine_data.duplicated(["Mouse ID", "Timepoint"] , keep=False)]

# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mouse_id = combine_data[combine_data.duplicated(["Mouse ID", "Timepoint"])]['Mouse ID'].unique()

duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mice = combine_data[combine_data['Mouse ID'].isin(duplicate_mouse_id)]

duplicate_mice
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = combine_data[combine_data["Mouse ID"].isin(duplicate_mouse_id) == False]
clean_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
clean_data_mouse_no = clean_data["Mouse ID"].nunique()
clean_data_mouse_no
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

mean = clean_data['Tumor Volume (mm3)'].groupby(clean_data['Drug Regimen']).mean()
median = clean_data['Tumor Volume (mm3)'].groupby(clean_data['Drug Regimen']).median()
var = clean_data['Tumor Volume (mm3)'].groupby(clean_data['Drug Regimen']).var()
std = clean_data['Tumor Volume (mm3)'].groupby(clean_data['Drug Regimen']).std()
sem = clean_data['Tumor Volume (mm3)'].groupby(clean_data['Drug Regimen']).sem()

summary_stat_df = pd.DataFrame({"Mean Tumor Volume":mean, 
                            "Median Tumor Volume":median, 
                           "Tumor Volume Variance":var, 
                           "Tumor Volume Std. Dev.":std, 
                           "Tumor Volume Std. Err.":sem}) 
# Assemble the resulting series into a single summary DataFrame.
summary_stat_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
summary_stats_single = combine_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(
    mean='mean',
    median='median',
    variance='var',
    std_dev='std',
    sem='sem'
)
# Using the aggregation method, produce the same summary statistics in a single line
summary_stats_single
# Out:
#                    mean     median   variance   std_dev       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
mouse_counts = combine_data.groupby('Drug Regimen').size().sort_values(ascending=False)
mouse_counts.plot(kind='bar', color='blue', figsize=(8, 6))
plt.title('Total Number of Mice per Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('# of observed Mouse Timepoints')
plt.tight_layout
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
mouse_counts = combine_data.groupby('Drug Regimen').size().sort_values(ascending=False)
plt.figure(figsize=(8, 6))
plt.bar(mouse_counts.index, mouse_counts.values, color='blue')
plt.xticks(rotation=90, ha='right')
plt.title('Total Number of Mice per Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('# of observed Mouse Timepoints')
plt.tight_layout
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study
mouse_counts = combine_data["Sex"].value_counts()
# Get the unique mice with their gender
mouse_counts

# Make the pie chart
mouse_counts_chart = mouse_counts.plot(kind="pie", autopct='%1.1f%%', labels=mouse_counts.index, figsize=(5, 5))
plt.tight_layout
plt.show()

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study
unique_mice_gender = combine_data["Sex"].value_counts()

# Get the unique mice with their gender
unique_mice_gender

# Make the pie chart
plt.pie(unique_mice_gender, labels=unique_mice_gender.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = combine_data.groupby('Mouse ID')['Timepoint'].max().reset_index()


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
last_timepoint_data = pd.merge(last_timepoint, combine_data, on=['Mouse ID', 'Timepoint'])

tumor_volume = last_timepoint_data[last_timepoint_data["Drug Regimen"].isin(treatment_regimens)]
tumor_volume.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 3     a275         45           62.999356                 3     Ceftamin
# 6     a411         45           38.407618                 1     Ramicane
# 7     a444         45           43.047543                 0     Ramicane
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 3  Female          20          28
# 6    Male           3          22
# 7  Female          10          25

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
for regimen in treatment_regimens:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_volumes = final_tumor_data[final_tumor_data['Drug Regimen'] == regimen]['Tumor Volume (mm3)']
    tumor_vol_data.append(tumor_volumes)
    # add subset
    Q1 = tumor_volumes.quantile(0.25)  # First quartile (25th percentile)
    Q3 = tumor_volumes.quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile Range
    # Determine outliers using upper and lower bounds
    lower_bound = Q1 - 1.5 * IQR  # Lower bound for outliers
    upper_bound = Q3 + 1.5 * IQR  # Upper bound for outliers
    if tumor_vol_data == 0:
        print(f"------------------------------------------------------------")
    print(f"The lower quartile of {treatment_regimens} treatments is: {Q1}")
    print(f"The upper quartile of {treatment_regimens} treatments is: {Q3}")
    print(f"The interquartile range of {treatment_regimens} treatments is: {IQR}")
    print(f"Values below {lower_bound} could be {treatment_regimens} outliers.")
    print(f"Values above {upper_bound} could be {treatment_regimens} outliers.")
    print(f"------------------------------------------------------------")
# Out:
# The lower quartile of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 32.37735684
# The upper quartile of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 40.1592203
# The interquartile range of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 7.781863460000004
# Values below 20.70456164999999 could be ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] outliers.
# Values above 51.83201549 could be ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] outliers.
# ------------------------------------------------------------
# The lower quartile of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 31.56046955
# The upper quartile of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 40.65900627
# The interquartile range of ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] treatments is: 9.098536719999998
# Values below 17.912664470000003 could be ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] outliers.
# ...

# %%
# Filter the final data to only include the four treatment regimens of interest
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
final_tumor_data_filtered = final_tumor_data[final_tumor_data['Drug Regimen'].isin(treatment_regimens)]

# Set up the figure size
plt.figure(figsize=(10, 6))

# Create a box plot using seaborn
#import seaborn as sns
#sns.boxplot(x='Drug Regimen', y='Tumor Volume (mm3)', data=final_tumor_data_filtered, palette='Set2', legend= False)
#sns.boxplot(x="Drug Regimen", y="Tumor Volume (mm3)", data=final_tumor_data_filtered, palette="Set3", showfliers=True)

# Add title and labels

plt.title('Tumor Volume Distribution by Treatment Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Tumor Volume (mm3)')
plt.xticks([1,2,3,4], treatment_regimens, rotation=90)
plt.boxplot(tumor_vol_data)
plt.legend(treatment_regimens)
          


# Show the plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
